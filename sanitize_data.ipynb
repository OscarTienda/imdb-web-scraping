# %% [markdown]
# # Import libraries and imdb dataset

# %%
import pandas as pd
import numpy as np
import random

# %%
imdb = pd.read_csv(r'C:\Users\oskarkrahe\Documents\Git\imdb-web-scraping\dataset\imdb.csv')
imdb.head(3)
# Out:
#              director  duration                    genre num_critic_reviews
# 0         Prabhu Deva     135.0    Action,Crime,Thriller                 22  \
# 1  M. Night Shyamalan     103.0  Action,Adventure,Family                291
# 2       David Benioff      80.0   Action,Adventure,Drama                361
#
#   num_user_reviews  rating                                              stars
# 0             2.5K     1.9  Salman Khan,Disha Patani,Randeep Hooda,Jackie ...  \
# 1             1.7K     1.9  Noah Ringer,Nicola Peltz Beckham,Jackson Rathb...
# 2             5.6K     1.9  Emilia Clarke,Peter Dinklage,Kit Harington,Len...
#
#                                              summary               title
# 0  "After taking the dreaded gangster Gani Bhai, ...               Radhe  \
# 1  "Follows the adventures of Aang, a young succe...  The Last Airbender
# 2  "Nine noble families fight for control over th...     Game of Thrones
#
#                                                  url   votes  year
# 0  https://www.imdb.com/title/tt10888594/?ref_=ad...  178458  2021
# 1  https://www.imdb.com/title/tt0938283/?ref_=adv...  166760  2010
# 2  https://www.imdb.com/title/tt0944947/?ref_=adv...  253670  2011

# %% [markdown]
# # Sanitization process
# The objective of this process is to create a sanitized dataset that is not vinculated to IMDb so that we can upload the file to Zenodo. The real dataset will be provided via Github private.

# %%
# Generate a new dataset.
movies_tv_shows = imdb.copy()

# Remove the 'url' column.
movies_tv_shows.drop(columns=['url'], inplace=True)

# Substitute 'rating' with a random number between 0 and 10 rounded to 2 digits.
movies_tv_shows['rating'] = round(np.random.uniform(0, 10), ndigits=2)

# Substitute 'votes' with random numbers between 150000  to 500000 rounded to 0 digits. 
movies_tv_shows['votes'] = round(np.random.uniform(150000, 500000))

# %% [markdown]
# Modifying the summary is more tricky: even though film and tv shows descriptions are pretty similar in all websites, I am not one hundred percent sure these summarys we're not written specifically for IMDb, so the data could still be related to them. We're going to remove the summarys by Lorem Ipsum text to avoid that chance.

# %%
# Lorem ipsum word list
word_list = ['lorem', 'ipsum', 'dolor', 'sit', 'amet', 'consectetur',
             'adipiscing', 'elit', 'integer', 'nec', 'odio', 'praesent']

# Function that replaces any word in the summary column by a random word in word_list
def replace_with_random_words(text, words):
    split_text = text.split()
    new_text = ' '.join([random.choice(words) for _ in split_text])
    return f'"{new_text}"'

movies_tv_shows['summary'] = movies_tv_shows['summary'].apply(lambda x: replace_with_random_words(x, word_list))

# %%
movies_tv_shows.head(10)
# Out:
#              director  duration                    genre num_critic_reviews
# 0         Prabhu Deva     135.0    Action,Crime,Thriller                 22  \
# 1  M. Night Shyamalan     103.0  Action,Adventure,Family                291
# 2       David Benioff      80.0   Action,Adventure,Drama                361
# 3  Sam Taylor-Johnson     125.0   Drama,Romance,Thriller                409
# 4          Josh Trank     100.0  Action,Adventure,Sci-Fi                420
# 5         Chris Weitz     130.0  Adventure,Drama,Fantasy                301
# 6  M. Night Shyamalan     100.0  Action,Adventure,Sci-Fi                280
# 7         Bill Condon     117.0  Adventure,Drama,Fantasy                328
# 8         David Slade     124.0   Action,Adventure,Drama                289
# 9  M. Night Shyamalan      91.0   Adventure,Drama,Sci-Fi                191
#
#   num_user_reviews  rating                                              stars
# 0             2.5K     9.6  Salman Khan,Disha Patani,Randeep Hooda,Jackie ...  \
# 1             1.7K     9.6  Noah Ringer,Nicola Peltz Beckham,Jackson Rathb...
# 2             5.6K     9.6  Emilia Clarke,Peter Dinklage,Kit Harington,Len...
# 3             1.6K     9.6  Dakota Johnson,Jamie Dornan,Jennifer Ehle,Eloi...
# 4              967     9.6  Miles Teller,Kate Mara,Michael B. Jordan,Jamie...
# 5              800     9.6  Kristen Stewart,Robert Pattinson,Taylor Lautne...
# 6              934     9.6  Jaden Smith,David Denman,Will Smith,Sophie Oko...
# 7              438     9.6  Kristen Stewart,Robert Pattinson,Taylor Lautne...
# 8              510     9.6  Kristen Stewart,Robert Pattinson,Taylor Lautne...
# 9             1.5K     9.6  Mark Wahlberg,Zooey Deschanel,John Leguizamo,A...
#
#                                              summary
# 0  "elit sit odio consectetur elit integer lorem ...  \
# 1  "lorem adipiscing consectetur ipsum praesent p...
# 2  "nec consectetur dolor odio sit integer nec lo...
# 3  "integer praesent dolor adipiscing dolor praes...
# 4  "praesent lorem sit praesent adipiscing elit c...
# 5  "nec adipiscing lorem elit lorem integer odio ...
# 6  "consectetur integer elit nec amet lorem nec a...
# 7  "adipiscing nec ipsum odio nec amet amet sit p...
# 8  "odio elit praesent praesent dolor praesent in...
# 9  "ipsum elit elit ipsum lorem integer praesent ...
#
#                                        title   votes  year
# 0                                      Radhe  337703  2021
# 1                         The Last Airbender  337703  2010
# 2                            Game of Thrones  337703  2011
# 3                       Fifty Shades of Grey  337703  2015
# 4                             Fantastic Four  337703  2015
# 5                The Twilight Saga: New Moon  337703  2009
# 6                                After Earth  337703  2013
# 7  The Twilight Saga: Breaking Dawn - Part 1  337703  2011
# 8                 The Twilight Saga: Eclipse  337703  2010
# 9                              The Happening  337703  2008

# %% [markdown]
# # Save the sanitized dataset

# %%
movies_tv_shows.to_csv(r'C:\Users\oskarkrahe\Documents\Git\imdb-web-scraping\dataset\movies_tv_shows.csv', index=False)
